# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma3:1b")
response = llm.invoke("What is the capital of France?")
response
# Out:
# AIMessage(content='The capital of France is **Paris**. \n\nIt’s a common misconception that it’s Lyon, but Paris is the official and historical capital. 😊 \n\nWould you like to know more about Paris?', additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2026-03-30T17:47:21.9390114Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3413589600, 'load_duration': 437396100, 'prompt_eval_count': 16, 'prompt_eval_duration': 387979200, 'eval_count': 44, 'eval_duration': 2520874600, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019d3fdb-6e7c-7df1-ace7-f5fbbfbf2644-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 44, 'total_tokens': 60})

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert AI Engineer. Please answer the question as best as you can."),
    ("user", "{input}")
])
output_parser = StrOutputParser()
chain=prompt|llm|output_parser
result = chain.invoke({"input": "What is the capital of France?"})
result
# type(result)
# Out:
# "Alright, let's settle this. As an AI Engineer, I can confidently answer that the capital of France is **Paris**.\n\nIt’s a well-established fact with a long history, and it’s the center of French culture, politics, and commerce. \n\nDo you have any other questions about France, or perhaps a related topic I can help you with?"
